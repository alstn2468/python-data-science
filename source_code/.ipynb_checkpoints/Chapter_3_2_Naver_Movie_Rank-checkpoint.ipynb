# %% [markdown]
# ## 네이버 영화 평점 기준 영화의 평점 변화 확인하기

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
from urllib.request import urlopen

url_base = "https://movie.naver.com/"
url_syb = "movie/sdb/rank/rmovie.nhn?sel=cur&data=20181104"

page = urlopen(url_base + url_syb)

soup = BeautifulSoup(page, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 " property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&amp;data=20181104" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %%
soup.find_all('div', 'tit5')
# Out:
# [<div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=156464" title="보헤미안 랩소디">보헤미안 랩소디</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=155356" title="미쓰백">미쓰백</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=150376" title="나, 다니엘 블레이크">나, 다니엘 블레이크</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=172174" title="어느 가족">어느 가족</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=175727" title="극장판 헬로카봇 : 백악기 시대">극장판 헬로카봇 : 백악기 시대</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=63403" title="타인의 삶">타인의 삶</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=168050" title="스타 이즈 본">스타 이즈 본</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=174301" title="카메라를 멈추면 안 돼!">카메라를 멈추면 안 돼!</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=177335" title="타샤 튜더">타샤 튜더</a>
#  </div>, <div class="tit5">
# ...

# %%
soup.find_all('div', 'tit5')[0].a.string
# Out:
# '보헤미안 랩소디'

# %%
soup.find_all('td', 'point')[0].string
# Out:
# '9.70'

# %%
date = pd.date_range('2018-7-27', periods = 100, freq = 'D')
date
# Out:
# DatetimeIndex(['2018-07-27', '2018-07-28', '2018-07-29', '2018-07-30',
#                '2018-07-31', '2018-08-01', '2018-08-02', '2018-08-03',
#                '2018-08-04', '2018-08-05', '2018-08-06', '2018-08-07',
#                '2018-08-08', '2018-08-09', '2018-08-10', '2018-08-11',
#                '2018-08-12', '2018-08-13', '2018-08-14', '2018-08-15',
#                '2018-08-16', '2018-08-17', '2018-08-18', '2018-08-19',
#                '2018-08-20', '2018-08-21', '2018-08-22', '2018-08-23',
#                '2018-08-24', '2018-08-25', '2018-08-26', '2018-08-27',
#                '2018-08-28', '2018-08-29', '2018-08-30', '2018-08-31',
#                '2018-09-01', '2018-09-02', '2018-09-03', '2018-09-04',
#                '2018-09-05', '2018-09-06', '2018-09-07', '2018-09-08',
#                '2018-09-09', '2018-09-10', '2018-09-11', '2018-09-12',
#                '2018-09-13', '2018-09-14', '2018-09-15', '2018-09-16',
# ...

# %%
import urllib
from tqdm import tqdm_notebook

movie_date = []
movie_name = []
movie_point = []

for today in tqdm_notebook(date) :
    html = 'https://movie.naver.com/' + \
            'movie/sdb/rank/rmovie.nhn?sel=cur&date={date}'
    response = urlopen(html.format(
                date = urllib.parse.quote(today.strftime('%Y%m%d'))))
    soup = BeautifulSoup(response, 'html.parser')
    
    end = len(soup.find_all('td', 'point'))
    
    movie_date.extend([today for n in range(0, end)])
    movie_name.extend([soup.find_all('div', 'tit5')[n].a.string for n in range(0, end)])
    movie_point.extend([soup.find_all('td', 'point')[n].string for n in range(0, end)])

# %%
movie = pd.DataFrame({'date' : movie_date, 
                      'name' : movie_name, 
                      'point' : movie_point})
movie['point'] = movie['point'].astype(float)
movie.head()
# Out:
#         date  name  point
# 0 2018-07-27   아일라   9.56
# 1 2018-07-27    당갈   9.56
# 2 2018-07-27  허스토리   9.42
# 3 2018-07-27    원더   9.41
# 4 2018-07-27    레옹   9.37

# %%
import numpy as np

movie_unique = pd.pivot_table(movie, index = ['name'], aggfunc = np.sum)
movie_best = movie_unique.sort_values(by = 'point', ascending = False)
movie_best.head()
# Out:
#                         point
# name
# 어느 가족                  904.71
# 소공녀                    861.70
# 신비아파트: 금빛 도깨비와 비밀의 동굴  806.50
# 극장판 헬로카봇 : 백악기 시대      785.42
# 맘마미아!2                 705.29

# %%
tmp = movie.query('name == ["베놈"]')
tmp
# Out:
#            date name  point
# 3267 2018-10-03   베놈   8.08
# 3303 2018-10-04   베놈   8.06
# 3338 2018-10-05   베놈   8.05
# 3373 2018-10-06   베놈   8.05
# 3408 2018-10-07   베놈   8.06
# 3443 2018-10-08   베놈   8.05
# 3481 2018-10-09   베놈   8.04
# 3520 2018-10-10   베놈   8.04
# 3554 2018-10-11   베놈   8.03
# 3589 2018-10-12   베놈   8.03
# 3623 2018-10-13   베놈   8.02
# 3658 2018-10-14   베놈   8.03
# 3693 2018-10-15   베놈   8.03
# 3733 2018-10-16   베놈   8.02
# 3771 2018-10-17   베놈   8.02
# 3811 2018-10-18   베놈   8.02
# 3844 2018-10-19   베놈   8.02
# 3881 2018-10-20   베놈   8.02
# 3917 2018-10-21   베놈   8.02
# 3957 2018-10-22   베놈   8.01
# 3999 2018-10-23   베놈   8.01
# 4040 2018-10-24   베놈   8.01
# 4078 2018-10-25   베놈   8.01
# 4117 2018-10-26   베놈   8.01
# 4154 2018-10-27   베놈   8.01
# 4191 2018-10-28   베놈   8.01
# 4229 2018-10-29   베놈   8.01
# 4268 2018-10-30   베놈   8.01
# 4311 2018-10-31   베놈   8.01
# 4353 2018-11-01   베놈   8.01
# 4390 2018-11-02   베놈   8.01
# 4428 2018-11-03   베놈   8.01

# %%
import matplotlib.pyplot as plt
% matplotlib inline

plt.figure(figsize = (12, 8))
plt.plot(tmp['date'], tmp['point'])
plt.legend(loc = 'best')
plt.grid()
plt.show()

# %% [markdown]
# ## 영화별 날짜 변화에 따른 평점 변화 확인하기

# %%
movie_pivot = pd.pivot_table(movie, index = ['date'],
                             columns = ['name'], values = ['point'])
movie_pivot.head()
# Out:
#            point                                                          \
# name        1987 500일의 썸머 5일의 마중 개들의 섬 건축학개론 걸어도 걸어도  경주 고양이를 빌려드립니다 곤지암
# date
# 2018-07-27   NaN      NaN    NaN  8.64  8.65    8.65 NaN         NaN NaN
# 2018-07-28   NaN     8.38    NaN  8.63  8.65    8.65 NaN         NaN NaN
# 2018-07-29   NaN     8.38    NaN  8.63  8.65    8.65 NaN         NaN NaN
# 2018-07-30   NaN     8.38    NaN  8.63  8.65    8.65 NaN         NaN NaN
# 2018-07-31   NaN     8.38    NaN  8.61  8.65    8.65 NaN         NaN NaN
#
#                            ...                                           \
# name       곰돌이 푸 다시 만나 행복해 ... 헝거게임 : 판엠의 불꽃 헝거게임: 캣칭 파이어 헝거게임:모킹제이 현기증
# date                       ...
# 2018-07-27             NaN ...           NaN          NaN       NaN NaN
# 2018-07-28             NaN ...           NaN          NaN       NaN NaN
# 2018-07-29             NaN ...           NaN          NaN       NaN NaN
# ...

# %%
movie_pivot.columns = movie_pivot.columns.droplevel()

# %%
movie_pivot.head()
# Out:
# name        1987  500일의 썸머  5일의 마중  개들의 섬  건축학개론  걸어도 걸어도  경주  고양이를 빌려드립니다  \
# date
# 2018-07-27   NaN       NaN     NaN   8.64   8.65     8.65 NaN          NaN
# 2018-07-28   NaN      8.38     NaN   8.63   8.65     8.65 NaN          NaN
# 2018-07-29   NaN      8.38     NaN   8.63   8.65     8.65 NaN          NaN
# 2018-07-30   NaN      8.38     NaN   8.63   8.65     8.65 NaN          NaN
# 2018-07-31   NaN      8.38     NaN   8.61   8.65     8.65 NaN          NaN
#
# name        곤지암  곰돌이 푸 다시 만나 행복해 ...   헝거게임 : 판엠의 불꽃  헝거게임: 캣칭 파이어  헝거게임:모킹제이  \
# date                             ...
# 2018-07-27  NaN              NaN ...             NaN           NaN        NaN
# 2018-07-28  NaN              NaN ...             NaN           NaN        NaN
# 2018-07-29  NaN              NaN ...             NaN           NaN        NaN
# 2018-07-30  NaN              NaN ...             NaN           NaN        NaN
# 2018-07-31  NaN              NaN ...             NaN           NaN        NaN
#
# ...

# %%
import platform
from matplotlib import font_manager, rc

path = 'c:/Windows/Fonts/malgun.ttf'

if platform.system() == 'Darwin' :
    rc('font', family = 'AppleGothic')
    
elif platform.system() == 'Windows' :
    font_name = font_manager.FontProperties(fname = path).get_name()
    rc('font', family = font_name)
    
else :
    print('Unknown system... Sorry~~~')

# %%
movie_pivot.plot(y = ['곤지암', '건축학개론', '1987', '창궐', '미쓰백'],
                 figsize = (12, 6))
plt.legend(loc = 'best')
plt.grid()
plt.show()
