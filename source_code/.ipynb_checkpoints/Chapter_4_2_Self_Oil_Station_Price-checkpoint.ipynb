# %% [markdown]
# # 셀프 주유소는 정말 저렴할까
#
#
# ## 서울시 구별 주유소 가격 정보 얻기

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome('../driver/chromedriver')
driver.get("http://www.opinet.co.kr/searRgSelect.do")

# %%
gu_list_raw = driver.find_element_by_xpath("""//*[@id="SIGUNGU_NM0"]""")
gu_list = gu_list_raw.find_elements_by_tag_name('option')

# %%
gu_names = [option.get_attribute('value') for option in gu_list]
gu_names.remove('')
gu_names
# Out:
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구']

# %%
element = driver.find_element_by_id("SIGUNGU_NM0")
element.send_keys(gu_names[0])

# %%
xpath = """//*[@id="searRgSelect"]"""
element_sel_gu = driver.find_element_by_xpath(xpath).click()

# %%
xpath = """//*[@id="glopopd_excel"]"""
element_get_excel = driver.find_element_by_xpath(xpath).click()

# %%
import time
from tqdm import tqdm_notebook

for gu in tqdm_notebook(gu_names):
    element = driver.find_element_by_id("SIGUNGU_NM0")
    element.send_keys(gu)
    
    time.sleep(2)
    
    xpath = """//*[@id="searRgSelect"]"""
    element_sel_gu = driver.find_element_by_xpath(xpath).click()
    
    time.sleep(1)
    
    xpath = """//*[@id="glopopd_excel"]"""
    element_get_excel = driver.find_element_by_xpath(xpath).click()
    
    time.sleep(1)
# Out:
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))

# %%
driver.close()

# %% [markdown]
# ## 구별 주유 가격에 대한 데이터의 정리

# %%
import pandas as pd
from glob import glob

# %%
glob('../data/지역_위치별*xls')
# Out:
# ['../data\\지역_위치별(주유소) (1).xls',
#  '../data\\지역_위치별(주유소) (10).xls',
#  '../data\\지역_위치별(주유소) (11).xls',
#  '../data\\지역_위치별(주유소) (12).xls',
#  '../data\\지역_위치별(주유소) (13).xls',
#  '../data\\지역_위치별(주유소) (14).xls',
#  '../data\\지역_위치별(주유소) (15).xls',
#  '../data\\지역_위치별(주유소) (16).xls',
#  '../data\\지역_위치별(주유소) (17).xls',
#  '../data\\지역_위치별(주유소) (18).xls',
#  '../data\\지역_위치별(주유소) (19).xls',
#  '../data\\지역_위치별(주유소) (2).xls',
#  '../data\\지역_위치별(주유소) (20).xls',
#  '../data\\지역_위치별(주유소) (21).xls',
#  '../data\\지역_위치별(주유소) (22).xls',
#  '../data\\지역_위치별(주유소) (23).xls',
#  '../data\\지역_위치별(주유소) (24).xls',
#  '../data\\지역_위치별(주유소) (3).xls',
#  '../data\\지역_위치별(주유소) (4).xls',
#  '../data\\지역_위치별(주유소) (5).xls',
#  '../data\\지역_위치별(주유소) (6).xls',
#  '../data\\지역_위치별(주유소) (7).xls',
#  '../data\\지역_위치별(주유소) (8).xls',
#  '../data\\지역_위치별(주유소) (9).xls',
#  '../data\\지역_위치별(주유소).xls']

# %%
stations_files = glob('../data/지역_위치별*xls')
stations_files
# Out:
# ['../data\\지역_위치별(주유소) (1).xls',
#  '../data\\지역_위치별(주유소) (10).xls',
#  '../data\\지역_위치별(주유소) (11).xls',
#  '../data\\지역_위치별(주유소) (12).xls',
#  '../data\\지역_위치별(주유소) (13).xls',
#  '../data\\지역_위치별(주유소) (14).xls',
#  '../data\\지역_위치별(주유소) (15).xls',
#  '../data\\지역_위치별(주유소) (16).xls',
#  '../data\\지역_위치별(주유소) (17).xls',
#  '../data\\지역_위치별(주유소) (18).xls',
#  '../data\\지역_위치별(주유소) (19).xls',
#  '../data\\지역_위치별(주유소) (2).xls',
#  '../data\\지역_위치별(주유소) (20).xls',
#  '../data\\지역_위치별(주유소) (21).xls',
#  '../data\\지역_위치별(주유소) (22).xls',
#  '../data\\지역_위치별(주유소) (23).xls',
#  '../data\\지역_위치별(주유소) (24).xls',
#  '../data\\지역_위치별(주유소) (3).xls',
#  '../data\\지역_위치별(주유소) (4).xls',
#  '../data\\지역_위치별(주유소) (5).xls',
#  '../data\\지역_위치별(주유소) (6).xls',
#  '../data\\지역_위치별(주유소) (7).xls',
#  '../data\\지역_위치별(주유소) (8).xls',
#  '../data\\지역_위치별(주유소) (9).xls',
#  '../data\\지역_위치별(주유소).xls']

# %%
tmp_raw = []

for file_name in stations_files:
    tmp = pd.read_excel(file_name, header=2)
    tmp_raw.append(tmp)
    
station_raw = pd.concat(tmp_raw)

# %%
station_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 519 entries, 0 to 41
# Data columns (total 10 columns):
# 지역       519 non-null object
# 상호       519 non-null object
# 주소       519 non-null object
# 상표       519 non-null object
# 전화번호     519 non-null object
# 셀프여부     519 non-null object
# 고급휘발유    519 non-null object
# 휘발유      519 non-null object
# 경유       519 non-null object
# 실내등유     519 non-null object
# dtypes: object(10)
# memory usage: 44.6+ KB

# %%
station_raw.head()
# Out:
#       지역                상호                          주소      상표         전화번호  \
# 0  서울특별시            구천면주유소       서울 강동구 구천면로 357 (암사동)  현대오일뱅크  02-441-0536
# 1  서울특별시    GS칼텍스㈜직영 신월주유소      서울 강동구 양재대로 1323 (성내동)   GS칼텍스  02-475-2600
# 2  서울특별시            동서울주유소  서울특별시 강동구  천호대로 1456 (상일동)   GS칼텍스  02-426-5372
# 3  서울특별시  주)지유에너지직영 오렌지주유소    서울특별시 강동구  성안로 102 (성내동)   SK에너지  02-484-6165
# 4  서울특별시   (주)퍼스트오일 코알라주유소   서울특별시 강동구  올림픽로 556 (성내동)   S-OIL  02-484-1162
#
#   셀프여부 고급휘발유   휘발유    경유  실내등유
# 0    N     -  1697  1495     -
# 1    N  1958  1707  1517  1140
# 2    Y     -  1708  1498     -
# 3    N     -  1716  1514  1097
# 4    Y     -  1718  1518     -

# %%
stations = pd.DataFrame({'Oil_store' : station_raw['상호'], 
                         '주소' : station_raw['주소'],
                         '가격' : station_raw['휘발유'],
                         '셀프' : station_raw['셀프여부'],
                         '상표' : station_raw['상표']  })
stations.head()
# Out:
#           Oil_store    가격      상표 셀프                          주소
# 0            구천면주유소  1697  현대오일뱅크  N       서울 강동구 구천면로 357 (암사동)
# 1    GS칼텍스㈜직영 신월주유소  1707   GS칼텍스  N      서울 강동구 양재대로 1323 (성내동)
# 2            동서울주유소  1708   GS칼텍스  Y  서울특별시 강동구  천호대로 1456 (상일동)
# 3  주)지유에너지직영 오렌지주유소  1716   SK에너지  N    서울특별시 강동구  성안로 102 (성내동)
# 4   (주)퍼스트오일 코알라주유소  1718   S-OIL  Y   서울특별시 강동구  올림픽로 556 (성내동)

# %%
stations['구'] = [eachAddress.split()[1] for eachAddress in stations['주소']]
stations.head()
# Out:
#           Oil_store    가격      상표 셀프                          주소    구
# 0            구천면주유소  1697  현대오일뱅크  N       서울 강동구 구천면로 357 (암사동)  강동구
# 1    GS칼텍스㈜직영 신월주유소  1707   GS칼텍스  N      서울 강동구 양재대로 1323 (성내동)  강동구
# 2            동서울주유소  1708   GS칼텍스  Y  서울특별시 강동구  천호대로 1456 (상일동)  강동구
# 3  주)지유에너지직영 오렌지주유소  1716   SK에너지  N    서울특별시 강동구  성안로 102 (성내동)  강동구
# 4   (주)퍼스트오일 코알라주유소  1718   S-OIL  Y   서울특별시 강동구  올림픽로 556 (성내동)  강동구

# %%
stations['구'].unique()
# Out:
# array(['강동구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '서울특별시', '성북구',
#        '송파구', '양천구', '영등포구', '강북구', '용산구', '은평구', '종로구', '중구', '중랑구',
#        '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '특별시', '강남구'], dtype=object)

# %%
stations[stations['구']=='서울특별시']
# Out:
#          Oil_store    가격     상표 셀프                           주소      구
# 13  SK네트웍스(주)효진주유소  1839  SK에너지  N  1 서울특별시 성동구 동일로 129 (성수동2가)  서울특별시

# %%
stations.loc[stations['구'] == '서울특별시', '구'] = '성동구'
stations['구'].unique()
# Out:
# array(['강동구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '강북구', '용산구', '은평구', '종로구', '중구', '중랑구', '강서구',
#        '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '특별시', '강남구'], dtype=object)

# %%
stations[stations['구'] == '특별시']
# Out:
#   Oil_store    가격     상표 셀프                        주소    구
# 3     서현주유소  1655  S-OIL  Y  서울 특별시 도봉구 방학로 142 (방학동)  특별시

# %%
stations.loc[stations['구'] == '특별시', '구'] = '도봉구'
stations['구'].unique()
# Out:
# array(['강동구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '강북구', '용산구', '은평구', '종로구', '중구', '중랑구', '강서구',
#        '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '강남구'], dtype=object)

# %%
stations[stations['가격'] == '-']
# Out:
#             Oil_store 가격      상표 셀프                          주소     구
# 13              서강주유소  -   SK에너지  N        서울 마포구 독막로 134 (창전동)   마포구
# 25              현대주유소  -   S-OIL  Y      서울 양천구 남부순환로 372 (신월동)   양천구
# 32         선익개발영등포주유소  -   SK에너지  N  서울 영등포구 경인로114길 2 (영등포동1가)  영등포구
# 33              대지주유소  -   SK에너지  N    서울 영등포구 영등포로 115 (당산동2가)  영등포구
# 34              하나주유소  -   S-OIL  N   서울특별시 영등포구  도림로 236 (신길동)  영등포구
# 17       대성산업(주)대성주유소  -   GS칼텍스  N        서울 은평구 통일로 642 (녹번동)   은평구
# 33    (주)한진 김포공항제2주유소  -   S-OIL  N              서울 강서구 하늘길 112   강서구
# 34              진일주유소  -   SK에너지  Y       서울 강서구 공항대로 533 (염창동)   강서구
# 17             대공원주유소  -   SK에너지  N   서울특별시 관악구  과천대로 921 (남현동)   관악구
# 21  현대오일뱅크(주)직영신구로주유소  -  현대오일뱅크  N   서울특별시 구로구  가마산로 293 (구로동)   구로구
# 41              동우주유소  -   SK에너지  N   서울특별시 강남구  봉은사로 311 (논현동)   강남구

# %%
stations = stations[stations['가격'] != '-']
stations.head()
# Out:
#           Oil_store    가격      상표 셀프                          주소    구
# 0            구천면주유소  1697  현대오일뱅크  N       서울 강동구 구천면로 357 (암사동)  강동구
# 1    GS칼텍스㈜직영 신월주유소  1707   GS칼텍스  N      서울 강동구 양재대로 1323 (성내동)  강동구
# 2            동서울주유소  1708   GS칼텍스  Y  서울특별시 강동구  천호대로 1456 (상일동)  강동구
# 3  주)지유에너지직영 오렌지주유소  1716   SK에너지  N    서울특별시 강동구  성안로 102 (성내동)  강동구
# 4   (주)퍼스트오일 코알라주유소  1718   S-OIL  Y   서울특별시 강동구  올림픽로 556 (성내동)  강동구

# %%
stations['가격'] = [float(value) for value in stations['가격']]

# %%
stations.reset_index(inplace=True)
del stations['index']

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 6 columns):
# Oil_store    508 non-null object
# 가격           508 non-null float64
# 상표           508 non-null object
# 셀프           508 non-null object
# 주소           508 non-null object
# 구            508 non-null object
# dtypes: float64(1), object(5)
# memory usage: 23.9+ KB

# %%
stations.head()
# Out:
#           Oil_store      가격      상표 셀프                          주소    구
# 0            구천면주유소  1697.0  현대오일뱅크  N       서울 강동구 구천면로 357 (암사동)  강동구
# 1    GS칼텍스㈜직영 신월주유소  1707.0   GS칼텍스  N      서울 강동구 양재대로 1323 (성내동)  강동구
# 2            동서울주유소  1708.0   GS칼텍스  Y  서울특별시 강동구  천호대로 1456 (상일동)  강동구
# 3  주)지유에너지직영 오렌지주유소  1716.0   SK에너지  N    서울특별시 강동구  성안로 102 (성내동)  강동구
# 4   (주)퍼스트오일 코알라주유소  1718.0   S-OIL  Y   서울특별시 강동구  올림픽로 556 (성내동)  강동구

# %% [markdown]
# ## 셀프 주유소는 정말 저렴한지 boxplot으로 확인하기

# %%
import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline

import platform

path = "c:/Windows/Fonts/malgun.ttf"

from matplotlib import font_manager, rc

if platform.system() == 'Darwin' :
    rc('font', family = 'AppleGothic')
    
elif platform.system() == 'Windows' :
    font_name = font_manager.FontProperties(fname = path).get_name()
    rc('font', family = font_name)
    
else :
    print('Unknown system... sorry~~~~')

# %%
stations.boxplot(column = '가격', by = '셀프', figsize = (12, 8))
# Out:
# C:\Users\Beginning\AppData\Roaming\Python\Python36\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
plt.figure(figsize = (12, 8))
sns.boxplot(x = "상표", y = "가격", hue = "셀프", 
            data = stations, palette = "Set3")
plt.show()

# %%
plt.figure(figsize = (12, 8))
sns.boxplot(x = "상표", y = "가격", data = stations, palette = "Set3")
sns.swarmplot(x = "상표", y = "가격", data = stations, color = ".6")
plt.show()

# %% [markdown]
# ## 서울시 구별 주유 가격 확인하기

# %%
import json
import folium
import googlemaps
import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
stations.sort_values(by = '가격', ascending = False).head(10)
# Out:
#           Oil_store      가격     상표 셀프                           주소    구
# 314           서남주유소  2328.0  SK에너지  N         서울 중구 통일로 30 (봉래동1가)   중구
# 313           장충주유소  2298.0  SK에너지  N       서울 중구 장충단로 202 (장충동1가)   중구
# 119           양재주유소  2296.0  SK에너지  N        서울 서초구 바우뫼로 178 (양재동)  서초구
# 507         뉴서울(강남)  2290.0  SK에너지  N         서울 강남구 언주로 716 (논현동)  강남구
# 160           삼선주유소  2198.0  S-OIL  N  서울특별시 성북구  창경궁로 324 (삼선동1가)  성북구
# 312           약수주유소  2196.0  GS칼텍스  N          서울 중구 다산로 173 (신당동)   중구
# 311  주)중앙에너비스 퇴계로지점  2195.0  SK에너지  N     서울특별시 중구  퇴계로 228 (필동2가)   중구
# 275            한남지점  2195.0  SK에너지  N       서울 용산구 한남대로21길 4 (한남동)  용산구
# 276            에너비스  2195.0  SK에너지  N       서울 용산구 한남대로21길 4 (한남동)  용산구
# 302  (주)중앙에너비스혜화주유소  2195.0  SK에너지  N       서울 종로구 창경궁로35길 1 (혜화동)  종로구

# %%
stations.sort_values(by = '가격', ascending = True).head(10)
# Out:
#             Oil_store      가격      상표 셀프                         주소     구
# 331         강서오곡셀프주유소  1627.0   SK에너지  Y    서울특별시 강서구 벌말로 254 (오곡동)   강서구
# 249          북서울고속주유소  1639.0   S-OIL  Y    서울특별시 강북구 삼양로 410 (수유동)   강북구
# 250            수유동주유소  1646.0   GS칼텍스  Y   서울특별시 강북구  도봉로 395 (수유동)   강북구
# 315    (주)자연에너지 대창주유소  1647.0  현대오일뱅크  N       서울 중랑구 동일로 636 (면목동)   중랑구
# 138             강산주유소  1647.0   GS칼텍스  N      서울 성북구 보문로 27 (보문동7가)   성북구
# 448   도봉제일주유소(주)송만에너지  1647.0  현대오일뱅크  N   서울특별시 도봉구  도봉로 783 (도봉동)   도봉구
# 449  한이에너지(주)KLP제1주유소  1647.0  현대오일뱅크  N    서울특별시 도봉구  도봉로 596 (창동)   도봉구
# 139             원천주유소  1649.0   알뜰주유소  N  서울특별시 성북구  돌곶이로 142 (장위동)   성북구
# 140             신방주유소  1652.0   S-OIL  N  서울특별시 성북구 안암로 111 (안암동5가)   성북구
# 18      재원에너지(주)용일주유소  1652.0   GS칼텍스  N       서울 동대문구 안암로 54 (용두동)  동대문구

# %%
import numpy as np

gu_data = pd.pivot_table(stations, index = ["구"], values = ["가격"], 
                         aggfunc = np.mean)
gu_data.head()
# Out:
#               가격
# 구
# 강남구  1899.634146
# 강동구  1768.111111
# 강북구  1681.384615
# 강서구  1719.242424
# 관악구  1724.588235

# %%
geo_path = '../data/02.skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding = 'utf-8'))

map = folium.Map(location = [37.5502, 126.982], zoom_start = 10.5, 
                 tiles = 'Stamen Toner')

map.choropleth(geo_data = geo_str,
               data = gu_data,
               columns = [gu_data.index, '가격'],
               fill_color = 'PuRd',
               key_on = 'feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 서울시 주유 가격 상하위 10개 주유소 지도에 표기하기

# %%
oil_price_top10 = stations.sort_values(by = '가격', ascending = False).head(10)
oil_price_top10
# Out:
#           Oil_store      가격     상표 셀프                           주소    구
# 314           서남주유소  2328.0  SK에너지  N         서울 중구 통일로 30 (봉래동1가)   중구
# 313           장충주유소  2298.0  SK에너지  N       서울 중구 장충단로 202 (장충동1가)   중구
# 119           양재주유소  2296.0  SK에너지  N        서울 서초구 바우뫼로 178 (양재동)  서초구
# 507         뉴서울(강남)  2290.0  SK에너지  N         서울 강남구 언주로 716 (논현동)  강남구
# 160           삼선주유소  2198.0  S-OIL  N  서울특별시 성북구  창경궁로 324 (삼선동1가)  성북구
# 312           약수주유소  2196.0  GS칼텍스  N          서울 중구 다산로 173 (신당동)   중구
# 311  주)중앙에너비스 퇴계로지점  2195.0  SK에너지  N     서울특별시 중구  퇴계로 228 (필동2가)   중구
# 275            한남지점  2195.0  SK에너지  N       서울 용산구 한남대로21길 4 (한남동)  용산구
# 276            에너비스  2195.0  SK에너지  N       서울 용산구 한남대로21길 4 (한남동)  용산구
# 302  (주)중앙에너비스혜화주유소  2195.0  SK에너지  N       서울 종로구 창경궁로35길 1 (혜화동)  종로구

# %%
oil_price_bottom10 = stations.sort_values(by = '가격', ascending = True).head(10)
oil_price_bottom10
# Out:
#             Oil_store      가격      상표 셀프                         주소     구
# 331         강서오곡셀프주유소  1627.0   SK에너지  Y    서울특별시 강서구 벌말로 254 (오곡동)   강서구
# 249          북서울고속주유소  1639.0   S-OIL  Y    서울특별시 강북구 삼양로 410 (수유동)   강북구
# 250            수유동주유소  1646.0   GS칼텍스  Y   서울특별시 강북구  도봉로 395 (수유동)   강북구
# 315    (주)자연에너지 대창주유소  1647.0  현대오일뱅크  N       서울 중랑구 동일로 636 (면목동)   중랑구
# 138             강산주유소  1647.0   GS칼텍스  N      서울 성북구 보문로 27 (보문동7가)   성북구
# 448   도봉제일주유소(주)송만에너지  1647.0  현대오일뱅크  N   서울특별시 도봉구  도봉로 783 (도봉동)   도봉구
# 449  한이에너지(주)KLP제1주유소  1647.0  현대오일뱅크  N    서울특별시 도봉구  도봉로 596 (창동)   도봉구
# 139             원천주유소  1649.0   알뜰주유소  N  서울특별시 성북구  돌곶이로 142 (장위동)   성북구
# 140             신방주유소  1652.0   S-OIL  N  서울특별시 성북구 안암로 111 (안암동5가)   성북구
# 18      재원에너지(주)용일주유소  1652.0   GS칼텍스  N       서울 동대문구 안암로 54 (용두동)  동대문구

# %%
gmap_key = '********'
gmaps = googlemaps.Client(key=gmap_key)

# %%
from tqdm import tqdm_notebook

lat = []
lng = []

for n in tqdm_notebook(oil_price_top10.index) :
    try :
        tmp_add = str(oil_price_top10['주소'][n]).split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)

        tmp_loc = tmp_map[0].get('geometry')
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
        
    except :
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan !")
        
oil_price_top10['lat'] = lat
oil_price_top10['lng'] = lng
oil_price_top10
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
#           Oil_store      가격     상표 셀프                           주소    구  \
# 314           서남주유소  2328.0  SK에너지  N         서울 중구 통일로 30 (봉래동1가)   중구
# 313           장충주유소  2298.0  SK에너지  N       서울 중구 장충단로 202 (장충동1가)   중구
# 119           양재주유소  2296.0  SK에너지  N        서울 서초구 바우뫼로 178 (양재동)  서초구
# 507         뉴서울(강남)  2290.0  SK에너지  N         서울 강남구 언주로 716 (논현동)  강남구
# 160           삼선주유소  2198.0  S-OIL  N  서울특별시 성북구  창경궁로 324 (삼선동1가)  성북구
# 312           약수주유소  2196.0  GS칼텍스  N          서울 중구 다산로 173 (신당동)   중구
# 311  주)중앙에너비스 퇴계로지점  2195.0  SK에너지  N     서울특별시 중구  퇴계로 228 (필동2가)   중구
# 275            한남지점  2195.0  SK에너지  N       서울 용산구 한남대로21길 4 (한남동)  용산구
# 276            에너비스  2195.0  SK에너지  N       서울 용산구 한남대로21길 4 (한남동)  용산구
# 302  (주)중앙에너비스혜화주유소  2195.0  SK에너지  N       서울 종로구 창경궁로35길 1 (혜화동)  종로구
#
#            lat         lng
# 314  37.558348  126.972090
# 313  37.562719  127.007010
# 119  37.478071  127.039610
# 507  37.517636  127.035756
# 160  37.587908  127.005575
# 312  37.559009  127.012663
# 311  37.561648  126.997142
# 275  37.534657  127.006063
# 276  37.534657  127.006063
# 302  37.586068  127.001058

# %%
lat = []
lng = []

for n in tqdm_notebook(oil_price_bottom10.index) :
    try :
        tmp_add = oil_price_bottom10['주소'][n].split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)

        tmp_loc = tmp_map[0]['geometry']
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
        
    except :
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan !")
    
oil_price_bottom10['lat'] = lat
oil_price_bottom10['lng'] = lng
oil_price_bottom10
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
#             Oil_store      가격      상표 셀프                         주소     구  \
# 331         강서오곡셀프주유소  1627.0   SK에너지  Y    서울특별시 강서구 벌말로 254 (오곡동)   강서구
# 249          북서울고속주유소  1639.0   S-OIL  Y    서울특별시 강북구 삼양로 410 (수유동)   강북구
# 250            수유동주유소  1646.0   GS칼텍스  Y   서울특별시 강북구  도봉로 395 (수유동)   강북구
# 315    (주)자연에너지 대창주유소  1647.0  현대오일뱅크  N       서울 중랑구 동일로 636 (면목동)   중랑구
# 138             강산주유소  1647.0   GS칼텍스  N      서울 성북구 보문로 27 (보문동7가)   성북구
# 448   도봉제일주유소(주)송만에너지  1647.0  현대오일뱅크  N   서울특별시 도봉구  도봉로 783 (도봉동)   도봉구
# 449  한이에너지(주)KLP제1주유소  1647.0  현대오일뱅크  N    서울특별시 도봉구  도봉로 596 (창동)   도봉구
# 139             원천주유소  1649.0   알뜰주유소  N  서울특별시 성북구  돌곶이로 142 (장위동)   성북구
# 140             신방주유소  1652.0   S-OIL  N  서울특별시 성북구 안암로 111 (안암동5가)   성북구
# 18      재원에너지(주)용일주유소  1652.0   GS칼텍스  N       서울 동대문구 안암로 54 (용두동)  동대문구
#
#            lat         lng
# 331  37.555284  126.768567
# 249  37.640155  127.017203
# 250  37.642140  127.029568
# 315  37.587170  127.080217
# 138  37.586954  127.017600
# 448  37.674434  127.044051
# 449  37.657714  127.040569
# 139  37.614921  127.052752
# 140  37.585504  127.031798
# 18   37.581382  127.028081

# %%
map = folium.Map(location = [37.5202, 126.975], zoom_start = 10.5)

for n in oil_price_top10.index :
    if pd.notnull(oil_price_top10['lat'][n]) :
        folium.CircleMarker([oil_price_top10['lat'][n], 
                             oil_price_top10['lng'][n]], 
                             radius = 15, color = '#CD3181', 
                             fill_color = '#CD3181', fill = True).add_to(map)
    
for n in oil_price_bottom10.index :
    if pd.notnull(oil_price_bottom10['lat'][n]) : 
        folium.CircleMarker([oil_price_bottom10['lat'][n], 
                             oil_price_bottom10['lng'][n]], 
                             radius = 15, color = '#3186cc', 
                             fill_color = '#3186cc', fill = True).add_to(map)
        
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
